# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import requests
import json
import random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
from scipy.stats import linregress, pearsonr
# %matplotlib inline
import matplotlib
from api_keys import weather_api_key

# %% [markdown]
# ## Generate Cities List

# %%
#Generate min. 1500 random latitude (-90 to 90) and longitude (-180 to 180) coordinates.

latitudes =[]
longitudes = []
for _ in range(1500): 
    latitude = random.randrange(-90, 90)
    longitude = random.randrange(-180, 180)
    latitudes.append(latitude)
    longitudes.append(longitude)

# %%
from citipy import citipy

cities = []
countries = []
for latitude, longitude in zip(latitudes, longitudes):
    location = citipy.nearest_city(latitude, longitude)
    city = location.city_name
    country = location.country_code
    cities.append(city)
    countries.append(country)

#Get rid of redundant cities in city list.
final_cities = []
for city in cities: 
    if city not in final_cities: 
        final_cities.append(city)

  

len(final_cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather_url = "http://api.openweathermap.org/data/2.5/weather?"

api_cities =[]
city_ids = []
countries = []
api_latitudes = []
api_longitudes = []
max_temps = []
humidities = []
clouds = []
wind_speeds = []
dates = []

for city in final_cities:
    query_url= f"{weather_url}q={city}&units=imperial&appid={weather_api_key}"
    city_weather = requests.get(query_url).json()
    try:
        city_name = city_weather["name"]
        city_id = city_weather["id"]
        print(f"Processing City = {city_name}, ID={city_id}...")
        api_cities.append(city_name)
        city_ids.append(city_id)
        countries.append(city_weather ["sys"]["country"])
        api_latitudes.append(city_weather["coord"]["lat"])
        api_longitudes.append(city_weather["coord"]["lon"])
        max_temps.append(city_weather["main"]["temp_max"])
        humidities.append(city_weather["main"]["humidity"])
        clouds.append(city_weather["clouds"]["all"])
        wind_speeds.append(city_weather["wind"]["speed"])
        dates.append(city_weather["dt"])
    except:
        print("City not found. Skipping...")
        pass

print("Complete ALL Searches!")
# Out:
# Processing City = Yellowknife, ID=6185377...
# Processing City = Dikson, ID=1507390...
# Processing City = Port Alfred, ID=964432...
# Processing City = Mahébourg, ID=934322...
# Processing City = Ushuaia, ID=3833367...
# Processing City = Tessalit, ID=2449893...
# Processing City = Saint-Philippe, ID=935215...
# Processing City = Nālūt, ID=2214432...
# Processing City = Severo-Kuril'sk, ID=2121385...
# Processing City = Bethel, ID=5282297...
# Processing City = Butaritari, ID=2110227...
# Processing City = Ayamé, ID=2292542...
# Processing City = Atuona, ID=4020109...
# City not found. Skipping...
# Processing City = Norman Wells, ID=6089245...
# Processing City = Busselton, ID=2075265...
# Processing City = Rikitea, ID=4030556...
# City not found. Skipping...
# Processing City = Arraial do Cabo, ID=3471451...
# Processing City = Avarua, ID=4035715...
# Processing City = Goundi, ID=2431736...
# Processing City = Faanui, ID=4034551...
# Processing City = Hoquiam, ID=5797693...
# Processing City = Saint George, ID=5546220...
# Processing City = Port Lincoln, ID=2063036...
# Processing City = Tuktoyaktuk, ID=6170031...
# City not found. Skipping...
# Processing City = Vaini, ID=4032243...
# Processing City = Cabañas, ID=3566573...
# Processing City = Bluff, ID=2206939...
# Processing City = Bengkulu, ID=1649150...
# Processing City = Chokurdakh, ID=2126123...
# Processing City = Hong Kong, ID=1819729...
# Processing City = Kapaa, ID=5848280...
# Processing City = Vestmannaeyjar, ID=3412093...
# Processing City = Albany, ID=5106841...
# Processing City = Erzin, ID=296852...
# Processing City = Guymon, ID=5515743...
# Processing City = Morgan City, ID=4333811...
# Processing City = Tarauacá, ID=3661980...
# Processing City = Río Gallegos, ID=3838859...
# City not found. Skipping...
# Processing City = Kiryat Gat, ID=293842...
# Processing City = Bac Lieu, ID=1591474...
# Processing City = Castro, ID=3466704...
# Processing City = Lorengau, ID=2092164...
# Processing City = Thompson, ID=6165406...
# Processing City = Khatanga, ID=2022572...
# City not found. Skipping...
# Processing City = Fareydūnshahr, ID=134601...
# Processing City = Cap Malheureux, ID=934649...
# Processing City = Mataura, ID=6201424...
# Processing City = Fare, ID=4034496...
# Processing City = Lingyuan, ID=2036075...
# Processing City = Ust-Nera, ID=2120048...
# Processing City = Nikolskoye, ID=546105...
# Processing City = Cabo San Lucas, ID=3985710...
# Processing City = Avera, ID=4231997...
# Processing City = Afikpo, ID=2352250...
# Processing City = Pisco, ID=3932145...
# Processing City = Hobart, ID=2163355...
# Processing City = Bathsheba, ID=3374083...
# City not found. Skipping...
# Processing City = Morant Bay, ID=3489440...
# Processing City = Nome, ID=5870133...
# Processing City = Lebu, ID=3883457...
# Processing City = Coquimbo, ID=3893629...
# Processing City = Provideniya, ID=4031574...
# Processing City = Bumba, ID=217745...
# Processing City = Harrismith, ID=997751...
# Processing City = Lavrentiya, ID=4031637...
# Processing City = Geraldton, ID=2070998...
# Processing City = Zyryanka, ID=2119283...
# Processing City = Verāval, ID=1253237...
# City not found. Skipping...
# Processing City = Bambous Virieux, ID=1106677...
# Processing City = Laredo, ID=4705349...
# Processing City = Hithadhoo, ID=1282256...
# Processing City = Touros, ID=3386213...
# Processing City = Krasnokamensk, ID=2021618...
# City not found. Skipping...
# Processing City = Umluj, ID=100926...
# Processing City = Tiksi, ID=2015306...
# Processing City = Ciudad Bolivar, ID=3645532...
# Processing City = Taunggyi, ID=1293960...
# Processing City = Portland, ID=5746545...
# Processing City = Mitsamiouli, ID=921786...
# Processing City = Hermanus, ID=3366880...
# Processing City = São Filipe, ID=3374210...
# Processing City = Baker City, ID=5712169...
# City not found. Skipping...
# Processing City = Padang, ID=1633419...
# Processing City = Gizo Government Station, ID=2108857...
# City not found. Skipping...
# Processing City = Ribeira Grande, ID=3372707...
# Processing City = Sydney, ID=2147714...
# Processing City = Aranos, ID=3358666...
# Processing City = Chabahar, ID=1161724...
# Processing City = Banepā, ID=1283679...
# Processing City = Hilo, ID=5855927...
# Processing City = Isangel, ID=2136825...
# Processing City = Juba, ID=373303...
# Processing City = Vieste, ID=3164387...
# Processing City = Husavik, ID=2629833...
# Processing City = Torbay, ID=6167817...
# Processing City = Itoigawa, ID=1861285...
# Processing City = Griffith, ID=4920986...
# Processing City = Bredasdorp, ID=1015776...
# Processing City = Sungai Raya, ID=1625908...
# Processing City = Ordzhonīkīdze, ID=1520381...
# Processing City = Blagoyevo, ID=576093...
# Processing City = Vila do Maio, ID=3374120...
# Processing City = New Norfolk, ID=2155415...
# Processing City = Port-Gentil, ID=2396518...
# Processing City = Samarai, ID=2132606...
# Processing City = Punta Arenas, ID=3874787...
# Processing City = Hungund, ID=1269876...
# Processing City = Kununurra, ID=2068110...
# Processing City = Lagos, ID=2332453...
# Processing City = Parrita, ID=3622537...
# Processing City = Brae, ID=2654970...
# Processing City = Carbonia, ID=2525362...
# Processing City = Rtishchevo, ID=500886...
# Processing City = Araouane, ID=2460954...
# Processing City = Narsaq, ID=3421719...
# Processing City = Meadow Lake, ID=5478673...
# Processing City = Kota Kinabalu, ID=1733432...
# Processing City = Qaanaaq, ID=3831208...
# Processing City = Vostok, ID=2013279...
# City not found. Skipping...
# Processing City = Guerrero Negro, ID=4021858...
# Processing City = Kawalu, ID=1640902...
# Processing City = Aljezur, ID=2271968...
# Processing City = Clyde River, ID=5924351...
# Processing City = Ponta do Sol, ID=2264557...
# Processing City = Yūbari, ID=2127419...
# Processing City = Caravelas, ID=3466980...
# Processing City = Kang, ID=933692...
# Processing City = Gimbi, ID=336496...
# Processing City = Barrow, ID=5880054...
# Processing City = Cape Town, ID=3369157...
# Processing City = Richards Bay, ID=962367...
# Processing City = Kahului, ID=5847411...
# Processing City = Bubaque, ID=2374583...
# Processing City = Souillac, ID=933995...
# Processing City = Sisimiut, ID=3419842...
# Processing City = Cidreira, ID=3466165...
# Processing City = George Town, ID=1735106...
# Processing City = Lompoc, ID=5367788...
# Processing City = Chui, ID=3443061...
# Processing City = Ipixuna, ID=3408424...
# Processing City = Boo, ID=2721259...
# Processing City = Fuerte Olimpo, ID=3438102...
# Processing City = Pochutla, ID=3517970...
# Processing City = Svit, ID=723411...
# Processing City = Safi, ID=2537881...
# Processing City = Mar del Plata, ID=3430863...
# Processing City = Kaitangata, ID=2208248...
# Processing City = Les Escoumins, ID=6944110...
# Processing City = Marystown, ID=6067472...
# Processing City = Lüderitz, ID=3355672...
# Processing City = Iquique, ID=3887127...
# Processing City = Pingliang, ID=1798760...
# Processing City = Port Hardy, ID=6111862...
# Processing City = Laas, ID=3175096...
# Processing City = Lhokseumawe, ID=1214658...
# City not found. Skipping...
# Processing City = Sabang, ID=1214026...
# Processing City = Jamestown, ID=5122534...
# Processing City = Shelburne, ID=6145890...
# Processing City = Nizāmābād, ID=1261258...
# Processing City = Keningau, ID=1734098...
# Processing City = Deputatsky, ID=2028164...
# Processing City = Nyakahanga, ID=151262...
# Processing City = Gazojak, ID=1514792...
# Processing City = Viranşehir, ID=298033...
# Processing City = Xiongzhou, ID=1788402...
# Processing City = Goulburn, ID=2164837...
# City not found. Skipping...
# Processing City = Tabora, ID=149658...
# Processing City = Suntar, ID=2015913...
# Processing City = Caceres, ID=2520610...
# Processing City = Torrington, ID=4844309...
# Processing City = Matara, ID=1235846...
# Processing City = Korla, ID=1529376...
# Processing City = Mapiri, ID=3910758...
# Processing City = Pitimbu, ID=3391889...
# Processing City = Tinskoy, ID=1489571...
# Processing City = Ol'ga, ID=2018553...
# Processing City = Djebeniana, ID=2470260...
# Processing City = Margate, ID=2643044...
# Processing City = Shimoda, ID=1852357...
# Processing City = Upernavik, ID=3418910...
# City not found. Skipping...
# Processing City = Aswān, ID=359792...
# Processing City = Gornyy, ID=1506254...
# Processing City = Ostrovnoy, ID=556268...
# Processing City = Namatanai, ID=2090021...
# Processing City = Graaff-Reinet, ID=1000543...
# Processing City = Pevek, ID=2122090...
# City not found. Skipping...
# Processing City = Eureka, ID=5563397...
# Processing City = Laguna, ID=5364271...
# Processing City = Tura, ID=1254046...
# Processing City = Airai, ID=1651810...
# Processing City = Nuuk, ID=3421319...
# Processing City = Aripuanã, ID=3665202...
# Processing City = Lake Charles, ID=4330236...
# Processing City = Yangi Marg`ilon, ID=1513491...
# Processing City = Iqaluit, ID=5983720...
# Processing City = Puerto Ayora, ID=3652764...
# Processing City = Noumea, ID=2139521...
# Processing City = Talnakh, ID=1490256...
# Processing City = Sistranda, ID=3139597...
# Processing City = Churapcha, ID=2025241...
# Processing City = Carnarvon, ID=2074865...
# Processing City = Saldanha, ID=3361934...
# City not found. Skipping...
# Processing City = Hosanagara, ID=1269946...
# Processing City = Barcelona, ID=3128760...
# Processing City = Saint-Augustin, ID=6137462...
# Processing City = Broome, ID=5110365...
# Processing City = Ikom, ID=2338242...
# Processing City = Berlevåg, ID=780687...
# Processing City = Yarkovo, ID=1486369...
# Processing City = Kota, ID=1266049...
# Processing City = Constitución, ID=3893726...
# Processing City = Vesele, ID=689736...
# Processing City = Alyangula, ID=2079582...
# Processing City = Kuytun, ID=2021093...
# Processing City = Dwārka, ID=1272140...
# Processing City = Ambilobe, ID=1082243...
# Processing City = Batouri, ID=2234663...
# City not found. Skipping...
# Processing City = Heihe, ID=2036973...
# Processing City = Chapais, ID=5919850...
# Processing City = Bayog, ID=1725747...
# Processing City = Tuatapere, ID=2180815...
# Processing City = Dicabisagan, ID=1715015...
# Processing City = Salamanca, ID=3111107...
# Processing City = Port Keats, ID=2063039...
# Processing City = Grindavik, ID=3416888...
# Processing City = Svetlaya, ID=2015852...
# Processing City = Roald, ID=3141667...
# Processing City = Arman', ID=2127060...
# Processing City = Jämsä, ID=656083...
# Processing City = Zhigansk, ID=2012530...
# Processing City = East London, ID=1006984...
# Processing City = Acarí, ID=3948613...
# City not found. Skipping...
# Processing City = Egvekinot, ID=4031742...
# Processing City = Northam, ID=2641434...
# Processing City = Mallaig, ID=6064804...
# Processing City = Kalmunai, ID=1242110...
# Processing City = Los Llanos de Aridane, ID=2514651...
# Processing City = Bahía Blanca, ID=3865086...
# Processing City = Coahuayana Viejo, ID=4013679...
# Processing City = Safaga, ID=358620...
# Processing City = Yerofey Pavlovich, ID=2012938...
# Processing City = Orlik, ID=1496073...
# Processing City = Tasiilaq, ID=3424607...
# Processing City = Sergeevka, ID=1519385...
# Processing City = Tegul'det, ID=1489822...
# Processing City = Turukhansk, ID=1488903...
# Processing City = Neiafu, ID=4032420...
# Processing City = Saint Paul Harbor, ID=5866583...
# Processing City = Beloha, ID=1067565...
# Processing City = Grand Gaube, ID=934479...
# Processing City = Hofn, ID=2630299...
# Processing City = Ust'-Kan, ID=1488190...
# Processing City = Butler, ID=4507568...
# Processing City = Spearfish, ID=5769288...
# Processing City = Vilyuysk, ID=2013392...
# Processing City = Kaunas, ID=598316...
# Processing City = Tres Arroyos, ID=3833859...
# Processing City = Alice Springs, ID=2077895...
# Processing City = Andenes, ID=3163146...
# Processing City = Tubmanburg, ID=2273435...
# Processing City = Twentynine Palms, ID=5404198...
# Processing City = Saskylakh, ID=2017155...
# Processing City = Smithers, ID=6149996...
# Processing City = Elizabeth City, ID=4465088...
# Processing City = Codrington, ID=2171099...
# Processing City = Melbourne, ID=4163971...
# Processing City = Taoudenni, ID=2450173...
# Processing City = Niquero, ID=3545981...
# Processing City = Karratha, ID=6620339...
# Processing City = Lagoa, ID=3372964...
# Processing City = Pokaran, ID=1259460...
# City not found. Skipping...
# Processing City = Kuril'sk, ID=2123979...
# Processing City = Yuzhno-Kurilsk, ID=2119447...
# Processing City = Hasaki, ID=2112802...
# Processing City = Burnie, ID=2173125...
# Processing City = Alta Floresta, ID=6316343...
# Processing City = Poli, ID=150689...
# Processing City = Borba, ID=3405051...
# Processing City = Baruun-Urt, ID=2032614...
# Processing City = Leningradskiy, ID=2123814...
# Processing City = Forsytheganj, ID=10722858...
# Processing City = Xining, ID=1788852...
# Processing City = Salalah, ID=286621...
# Processing City = Longyan, ID=1802276...
# Processing City = Bonthe, ID=2409914...
# City not found. Skipping...
# Processing City = Dubbo, ID=2168305...
# Processing City = Hamilton, ID=4513583...
# Processing City = Dalianwan, ID=1921372...
# Processing City = Nurota, ID=1513087...
# Processing City = Porto Santo, ID=8010683...
# Processing City = Beruwala, ID=1249931...
# Processing City = Ganzhou, ID=1810637...
# Processing City = Charlestown, ID=2171766...
# Processing City = Ginir, ID=336454...
# City not found. Skipping...
# Processing City = Nanortalik, ID=3421765...
# Processing City = Fairbanks, ID=5861897...
# Processing City = Lata, ID=2738381...
# Processing City = Aconibe, ID=2310547...
# City not found. Skipping...
# Processing City = Tahe, ID=2034615...
# Processing City = Pacific Grove, ID=5380437...
# Processing City = Hervey Bay, ID=2146219...
# Processing City = Salym, ID=1493162...
# Processing City = Buta, ID=217570...
# Processing City = Arrifes, ID=3373329...
# Processing City = Biak, ID=1637001...
# Processing City = Rocha, ID=3440777...
# City not found. Skipping...
# Processing City = Oskarshamn, ID=2686162...
# Processing City = Camacha, ID=2270385...
# Processing City = Tauá, ID=3386568...
# Processing City = Meulaboh, ID=1214488...
# Processing City = Cabra, ID=2520645...
# Processing City = Todos Santos, ID=3981432...
# Processing City = Smolenskaya Oblast’, ID=491684...
# Processing City = Kavaratti, ID=1267390...
# Processing City = Yima, ID=1786676...
# Processing City = Necochea, ID=3430443...
# Processing City = Teluk Anson, ID=1735459...
# Processing City = Lemta, ID=2469571...
# Processing City = Lere, ID=2332079...
# Processing City = Krasnosel'kup, ID=1502073...
# Processing City = Suicheng, ID=1793899...
# Processing City = San Cristobal, ID=3628473...
# Processing City = Sattahip, ID=1606386...
# City not found. Skipping...
# Processing City = São José da Coroa Grande, ID=3388456...
# Processing City = Gigmoto, ID=1712961...
# Processing City = Zabul Province, ID=1121143...
# Processing City = Sittwe, ID=1295765...
# Processing City = Pszczyna, ID=3087705...
# Processing City = Beisfjord, ID=3144987...
# Processing City = Carballo, ID=3126369...
# Processing City = Nabire, ID=1634614...
# Processing City = Coolum Beach, ID=2170581...
# Processing City = Oleksandrivka, ID=698627...
# Processing City = Fukuechō, ID=1863997...
# Processing City = Boquira, ID=3469190...
# Processing City = Tokmak, ID=691469...
# City not found. Skipping...
# Processing City = Labytnangi, ID=1500933...
# Processing City = Maningrida, ID=2067089...
# Processing City = Cheney, ID=5789856...
# Processing City = Velyka Bahachka, ID=690285...
# City not found. Skipping...
# Processing City = Manacapuru, ID=3663529...
# Processing City = Saint-Paul, ID=935221...
# Processing City = Arlit, ID=2447513...
# Processing City = Sitka, ID=5557293...
# Processing City = Nevşehir, ID=303830...
# Processing City = Duku, ID=2344415...
# City not found. Skipping...
# Processing City = Huarmey, ID=3939168...
# Processing City = Fortuna, ID=5563839...
# Processing City = Mossamedes, ID=3347019...
# Processing City = Lugazi, ID=229911...
# City not found. Skipping...
# Processing City = Telfs, ID=2763810...
# Processing City = El Alto, ID=3697441...
# Processing City = Bonavista, ID=5905393...
# Processing City = Port Elizabeth, ID=964420...
# Processing City = Kenai, ID=5866063...
# Processing City = Jijiga, ID=333795...
# Processing City = Dumai, ID=1645133...
# Processing City = Methóni, ID=257122...
# Processing City = Muros, ID=3115824...
# Processing City = Dahuk, ID=96994...
# Processing City = Port Said, ID=358619...
# Processing City = Archidona, ID=2521673...
# Processing City = Sovetskaya, ID=490065...
# Processing City = Olinda, ID=3393536...
# Processing City = Vila Velha, ID=3445026...
# Processing City = Hambantota, ID=1244926...
# Processing City = Mindelo, ID=3374462...
# Processing City = Karatau, ID=1519938...
# Processing City = Cayenne, ID=3382160...
# Processing City = Quatre Cocos, ID=1106643...
# Processing City = Vardø, ID=777019...
# Processing City = Khorixas, ID=3356213...
# Processing City = Voghera, ID=3163995...
# Processing City = Chara, ID=2025630...
# Processing City = Saint-Pierre, ID=935214...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing City = Arraias, ID=3454606...
# Processing City = Hobyo, ID=57000...
# Processing City = Portoferraio, ID=3170094...
# Processing City = Calamar, ID=3687972...
# Processing City = Srednekolymsk, ID=2121025...
# Processing City = Longyearbyen, ID=2729907...
# Processing City = Cherskiy, ID=2126199...
# Processing City = Port Blair, ID=1259385...
# City not found. Skipping...
# Processing City = Kavieng, ID=2094342...
# Processing City = Kemijärvi, ID=653272...
# Processing City = Esperance, ID=2071860...
# Processing City = Flinders, ID=6255012...
# Processing City = Januária, ID=3460148...
# Processing City = Bitam, ID=2401578...
# Processing City = Campoverde, ID=3733380...
# Processing City = Pontal do Paraná, ID=6322927...
# Processing City = Keti Bandar, ID=1174451...
# Processing City = Lerwick, ID=2644605...
# Processing City = Paraná, ID=3841956...
# Processing City = Marzuq, ID=72181...
# Processing City = Daru, ID=2098329...
# Processing City = Tongren, ID=1792592...
# Processing City = Dingle, ID=1714733...
# Processing City = Tilichiki, ID=2120591...
# Processing City = Naze, ID=1855540...
# Processing City = Nimāparha, ID=1261375...
# Processing City = Mahibadhoo, ID=1337605...
# Processing City = Görele, ID=746565...
# Processing City = Faya, ID=110690...
# Processing City = Kiruna, ID=605155...
# Processing City = Anadyr, ID=2127202...
# Processing City = Juneau, ID=5554072...
# City not found. Skipping...
# Processing City = Newport, ID=2641598...
# Processing City = Powassan, ID=6112530...
# Processing City = Bafra, ID=751335...
# Processing City = Kota Belud, ID=1736660...
# Processing City = Arrondissement de Rochefort, ID=2983272...
# Processing City = Te Anau, ID=2181625...
# Processing City = Vagay, ID=1487860...
# Processing City = Artvin Province, ID=751816...
# Processing City = The Valley, ID=3573374...
# Processing City = Loukhi, ID=533964...
# Processing City = Prince George, ID=6113365...
# Processing City = Romny, ID=695464...
# Processing City = Atasū, ID=1526041...
# Processing City = Olafsvik, ID=3414079...
# Processing City = Choma, ID=917748...
# Processing City = Port Augusta, ID=2063056...
# Processing City = Gao, ID=2457161...
# Processing City = Port Pirie, ID=2063030...
# Processing City = Kunduz, ID=1135689...
# Processing City = Yining, ID=1786538...
# Processing City = Dandong, ID=2037886...
# Processing City = Pangnirtung, ID=6096551...
# Processing City = Oranjemund, ID=3354071...
# Processing City = Bratsk, ID=2051523...
# Processing City = Aktau, ID=610612...
# Processing City = Half Moon Bay, ID=5354943...
# Processing City = Dzaoudzi, ID=921900...
# Processing City = Sonoita, ID=3982837...
# City not found. Skipping...
# Processing City = Darlawn, ID=1273463...
# Processing City = Valparaíso, ID=3868626...
# Processing City = Waddān, ID=2209055...
# Processing City = Mount Gambier, ID=2156643...
# Processing City = ‘Āhuimanu, ID=5856516...
# Processing City = Katobu, ID=1640972...
# Processing City = Landskrona, ID=2697720...
# City not found. Skipping...
# Processing City = Baykit, ID=1510689...
# Processing City = Erzurum Province, ID=315367...
# Processing City = Bay City, ID=4985180...
# Processing City = Bilibino, ID=2126682...
# Processing City = Solone, ID=693231...
# City not found. Skipping...
# Processing City = Mackenzie, ID=6063191...
# Processing City = Matveyevka, ID=528521...
# Processing City = Klaksvík, ID=2618795...
# City not found. Skipping...
# Processing City = Pundaguitan, ID=1698289...
# Processing City = Awjilah, ID=88533...
# Processing City = Granger, ID=4920869...
# Processing City = Vaitape, ID=4033077...
# Processing City = San Patricio, ID=4726521...
# Processing City = Ahipara, ID=2194098...
# Processing City = Morón, ID=3430545...
# Processing City = Kaniama, ID=214389...
# Processing City = Malé, ID=1282027...
# Processing City = Orán, ID=3836620...
# Processing City = Rafaela, ID=3839479...
# Processing City = Bo Phloi, ID=1153850...
# Processing City = Atar, ID=2381334...
# Processing City = Chiredzi, ID=893485...
# City not found. Skipping...
# Processing City = Haywards Heath, ID=2647248...
# Processing City = Barcelos, ID=2742416...
# Processing City = Surgut, ID=1490624...
# Processing City = Kaihua, ID=1804874...
# Processing City = Ailigandí, ID=3714956...
# Processing City = Yanam, ID=1252795...
# Processing City = Nishihara, ID=1855342...
# Processing City = Villa Carlos Paz, ID=3832791...
# Processing City = Plettenberg Bay, ID=964712...
# Processing City = Santiago del Estero, ID=3835869...
# Processing City = Madona, ID=457714...
# City not found. Skipping...
# Processing City = Champerico, ID=3598787...
# Processing City = Nago, ID=1856068...
# Processing City = Ledyard Center, ID=4837648...
# Processing City = Kautokeino, ID=779330...
# Processing City = Lady Lake, ID=4161118...
# Processing City = Ciudad Real, ID=2519401...
# Processing City = Nyaunglebin, ID=1303406...
# Processing City = Leh, ID=1264976...
# Processing City = Presidencia Roque Sáenz Peña, ID=3840300...
# Processing City = Khovd, ID=1516048...
# Processing City = Rivera, ID=3440781...
# Processing City = Itamaracá, ID=3397963...
# Processing City = Horta, ID=3372988...
# Processing City = Matagami, ID=6067747...
# Processing City = Ballina, ID=2177069...
# Processing City = Rāvar, ID=118704...
# Processing City = Sobolevo, ID=525426...
# Processing City = Maniitsoq, ID=3421982...
# Processing City = Mahajanga, ID=1062663...
# Processing City = Gatbo, ID=1713131...
# Processing City = Popondetta, ID=2088163...
# Processing City = Leshukonskoye, ID=535839...
# Processing City = Chingirlau, ID=610091...
# Processing City = Mbale, ID=229278...
# Processing City = Shchors, ID=694273...
# Processing City = Puerto Escondido, ID=3520994...
# Processing City = Belmonte, ID=3470137...
# City not found. Skipping...
# City not found. Skipping...
# Processing City = Amapá, ID=3407762...
# Processing City = Kokopo, ID=2093685...
# Processing City = Mingora, ID=1170395...
# Processing City = Burgeo, ID=5911440...
# Processing City = Storforshei, ID=3145614...
# Processing City = Raudeberg, ID=3146487...
# Processing City = Norfolk, ID=4945455...
# Processing City = Salamiyah, ID=164947...
# Processing City = Byron Bay, ID=2172880...
# Processing City = Angoche, ID=1052944...
# Processing City = Bilāspur, ID=1275637...
# Processing City = Llanes, ID=3118304...
# Processing City = Aykhal, ID=2027296...
# Processing City = Comodoro Rivadavia, ID=3860443...
# Processing City = Maceió, ID=3395981...
# Processing City = Vitória da Conquista, ID=3444914...
# Processing City = Saint Simons, ID=4220862...
# Processing City = Cilegon, ID=1627549...
# Processing City = Ximeicun, ID=1789289...
# Processing City = Ponta Delgada, ID=3372783...
# Processing City = Zhangaözen, ID=607610...
# City not found. Skipping...
# Processing City = Cukai, ID=1732945...
# Processing City = Warmbad, ID=3352263...
# Processing City = Tysmenytsya, ID=690873...
# Processing City = Hualmay, ID=3939761...
# Processing City = Sechura, ID=3691954...
# Processing City = Kondinskoye, ID=1502697...
# Processing City = Kysyl-Syr, ID=2021017...
# Processing City = Łomża, ID=766027...
# Processing City = Bariloche, ID=7647007...
# Processing City = Amahai, ID=1651591...
# Processing City = Dakar, ID=2253354...
# Processing City = São João da Barra, ID=3448903...
# Processing City = Haines Junction, ID=5969025...
# Processing City = Ko Samui, ID=1154689...
# Processing City = Makar'yev, ID=532138...
# Processing City = Stromness, ID=2636638...
# Processing City = Rosario, ID=3838583...
# Processing City = Seoul, ID=1835848...
# Processing City = Port Hedland, ID=2063042...
# Processing City = Watertown, ID=4954611...
# Processing City = Tsimmerbude, ID=485660...
# Processing City = Along, ID=1278969...
# Processing City = Kostanay, ID=1519928...
# Processing City = Kalulushi, ID=914959...
# Processing City = San Quintín, ID=3984997...
# Processing City = Gamba, ID=2400547...
# Processing City = Sept-Îles, ID=6144312...
# Processing City = Bone, ID=2937959...
# Processing City = Formosa do Rio Preto, ID=3463124...
# Processing City = Umm Hājar, ID=2426370...
# Processing City = Rongcheng, ID=1797117...
# Processing City = Mazamari, ID=3935102...
# Processing City = Saltpond, ID=2295672...
# Processing City = Hirara, ID=1862505...
# Processing City = Cockburn Town, ID=3576994...
# Processing City = Udachny, ID=2014624...
# Processing City = Vágur, ID=2610806...
# Processing City = Dunedin, ID=2191562...
# Processing City = Mount Isa, ID=2065594...
# City not found. Skipping...
# Processing City = Adrar, ID=2381972...
# Processing City = Birao, ID=240210...
# Processing City = Luján, ID=3430988...
# Processing City = Kupang, ID=2057087...
# Processing City = Atambua, ID=1651103...
# Processing City = Aklavik, ID=5882953...
# Processing City = Pangkalanbuun, ID=1632694...
# Processing City = Bay Roberts, ID=5895424...
# Processing City = Solnechnyy, ID=2016307...
# Processing City = Tuljāpur, ID=1254111...
# Processing City = Wau, ID=363885...
# Processing City = Peniche, ID=2264923...
# Processing City = Coyhaique, ID=3894426...
# Processing City = Eyl, ID=60019...
# Processing City = Yenagoa, ID=2318123...
# Processing City = Manzhouli, ID=2035836...
# Processing City = Phalaborwa, ID=965528...
# Complete ALL Searches!

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
all_cities_df = pd.DataFrame({
    "City ID": city_ids,
    "City": api_cities,
    "Country": countries,
    "Latitude": api_latitudes,
    "Longitude": api_longitudes,
    "Max Temp (F)" : max_temps,
    "Humidity (%)": humidities,
    "Cloudiness (%)": clouds,
    "Wind Speed (mph)": wind_speeds,
    "Date": dates
})

#Export the city data (all_cities_df) into a csv file (all_cities_csv).
all_cities_df.to_csv(r"all_cities.csv",index=False)

#Display the DataFrame.
all_cities_df
# Out:
#      City ID         City Country  Latitude  Longitude  Max Temp (F)  \
# 0    6185377  Yellowknife      CA     62.46    -114.35         25.00
# 1    1507390       Dikson      RU     73.51      80.55         17.96
# 2     964432  Port Alfred      ZA    -33.59      26.89         61.74
# 3     934322    Mahébourg      MU    -20.41      57.70         69.80
# 4    3833367      Ushuaia      AR    -54.80     -68.30         41.00
# ..       ...          ...     ...       ...        ...           ...
# 574  3894426    Coyhaique      CL    -45.58     -72.07         48.20
# 575    60019          Eyl      SO      7.98      49.82         80.24
# 576  2318123      Yenagoa      NG      4.92       6.26         74.71
# 577  2035836    Manzhouli      CN     49.60     117.43         37.38
# 578   965528   Phalaborwa      ZA    -23.94      31.14         62.60
#
#      Humidity (%)  Cloudiness (%)  Wind Speed (mph)        Date
# 0              85              90             16.11  1602901586
# 1              95               4             15.03  1602901814
# 2              82              14              8.05  1602901814
# 3              88              40              5.82  1602901814
# 4              65              40             19.46  1602901815
# ..            ...             ...               ...         ...
# 574            76              12              2.24  1602901903
# 575            74              88             11.83  1602901903
# 576            95             100              2.24  1602901903
# 577            69              30             17.67  1602901903
# 578            88              74              4.70  1602901904
#
# [579 rows x 10 columns]

# %%
#Remove redundant cities in all_cities_df and get final city counts.

unique_cities_df = all_cities_df.drop_duplicates(subset=["City"])

unique_cities_df["City"].value_counts()
# Out:
# Nishihara          1
# Muros              1
# Artvin Province    1
# Luján              1
# Popondetta         1
#                   ..
# Faanui             1
# Bilibino           1
# Taunggyi           1
# Beisfjord          1
# Kautokeino         1
# Name: City, Length: 579, dtype: int64

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
unique_cities_df.loc[unique_cities_df["Humidity (%)"] > 100,:]

# CONCLUSION: NO CITIES OVER 100% humidity.
# Out:
# Empty DataFrame
# Columns: [City ID, City, Country, Latitude, Longitude, Max Temp (F), Humidity (%), Cloudiness (%), Wind Speed (mph), Date]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

clean_city_data = unique_cities_df


clean_city_data.to_csv("cities_weather_data.csv")
clean_city_data
# Out:
#      City ID         City Country  Latitude  Longitude  Max Temp (F)  \
# 0    6185377  Yellowknife      CA     62.46    -114.35         25.00
# 1    1507390       Dikson      RU     73.51      80.55         17.96
# 2     964432  Port Alfred      ZA    -33.59      26.89         61.74
# 3     934322    Mahébourg      MU    -20.41      57.70         69.80
# 4    3833367      Ushuaia      AR    -54.80     -68.30         41.00
# ..       ...          ...     ...       ...        ...           ...
# 574  3894426    Coyhaique      CL    -45.58     -72.07         48.20
# 575    60019          Eyl      SO      7.98      49.82         80.24
# 576  2318123      Yenagoa      NG      4.92       6.26         74.71
# 577  2035836    Manzhouli      CN     49.60     117.43         37.38
# 578   965528   Phalaborwa      ZA    -23.94      31.14         62.60
#
#      Humidity (%)  Cloudiness (%)  Wind Speed (mph)        Date
# 0              85              90             16.11  1602901586
# 1              95               4             15.03  1602901814
# 2              82              14              8.05  1602901814
# 3              88              40              5.82  1602901814
# 4              65              40             19.46  1602901815
# ..            ...             ...               ...         ...
# 574            76              12              2.24  1602901903
# 575            74              88             11.83  1602901903
# 576            95             100              2.24  1602901903
# 577            69              30             17.67  1602901903
# 578            88              74              4.70  1602901904
#
# [579 rows x 10 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
lat_temp_scat = clean_city_data.plot(x="Latitude", y="Max Temp (F)", kind="scatter")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (F)")
plt.title ("City Latitude vs. Maximum Temperature")
plt.yticks(np.arange(1, 110, 10))
plt.grid()
plt.savefig("cities_lat_temp.png")
plt.show()
plt.tight_layout()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
lat_temp_scat = clean_city_data.plot(x="Latitude", y="Humidity (%)", kind="scatter")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title ("City Latitude vs. Humidity")
plt.yticks(np.arange(0, 110, 10))
plt.grid()
plt.savefig("cities_lat_humid.png")
plt.show()
plt.tight_layout()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat_temp_scat = clean_city_data.plot(x="Latitude", y="Cloudiness (%)", kind="scatter")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title ("City Latitude vs. Cloudiness")
plt.yticks(np.arange(0, 110, 10))
plt.grid()
plt.savefig("cities_lat_cloudy.png")
plt.show()
plt.tight_layout()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat_temp_scat = clean_city_data.plot(x="Latitude", y="Wind Speed (mph)", kind="scatter")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title ("City Latitude vs. Wind Speed")
plt.yticks(np.arange(0, 60, 10))
plt.grid()
plt.savefig("cities_lat_wind.png")
plt.show()
plt.tight_layout()

# %% [markdown]
# ## Linear Regression

# %%
#Create Weather dataframe for Northern Hemisphere Cities.
Northern_cities = clean_city_data.loc[(clean_city_data["Latitude"] >= 0), :]
Northern_cities.to_csv("Northerncities_weather_data.csv")
Northern_cities
# Out:
#      City ID             City Country  Latitude  Longitude  Max Temp (F)  \
# 0    6185377      Yellowknife      CA     62.46    -114.35         25.00
# 1    1507390           Dikson      RU     73.51      80.55         17.96
# 5    2449893         Tessalit      ML     20.20       1.01         81.32
# 7    2214432            Nālūt      LY     30.33      10.85         62.87
# 8    2121385  Severo-Kuril'sk      RU     50.68     156.12         43.57
# ..       ...              ...     ...       ...        ...           ...
# 572   363885              Wau      SS      7.70      28.00         72.18
# 573  2264923          Peniche      PT     39.36      -9.38         52.00
# 575    60019              Eyl      SO      7.98      49.82         80.24
# 576  2318123          Yenagoa      NG      4.92       6.26         74.71
# 577  2035836        Manzhouli      CN     49.60     117.43         37.38
#
#      Humidity (%)  Cloudiness (%)  Wind Speed (mph)        Date
# 0              85              90             16.11  1602901586
# 1              95               4             15.03  1602901814
# 5              16               0              8.66  1602901815
# 7              75              66             17.34  1602901815
# 8              66              83             25.66  1602901815
# ..            ...             ...               ...         ...
# 572            94              99              3.98  1602901903
# 573            99             100              3.20  1602901903
# 575            74              88             11.83  1602901903
# 576            95             100              2.24  1602901903
# 577            69              30             17.67  1602901903
#
# [405 rows x 10 columns]

# %%
#Create Weather datafram for Southern Hemisphere Cities.

Southern_cities = clean_city_data.loc[(clean_city_data["Latitude"] <= 0), :]
Southern_cities.to_csv("Southerncities_weather_data.csv")
Southern_cities
# Out:
#      City ID            City Country  Latitude  Longitude  Max Temp (F)  \
# 2     964432     Port Alfred      ZA    -33.59      26.89         61.74
# 3     934322       Mahébourg      MU    -20.41      57.70         69.80
# 4    3833367         Ushuaia      AR    -54.80     -68.30         41.00
# 6     935215  Saint-Philippe      RE    -21.36      55.77         70.00
# 12   4020109          Atuona      PF     -9.80    -139.03         78.73
# ..       ...             ...     ...       ...        ...           ...
# 565  2057087          Kupang      ID    -10.17     123.58         87.80
# 566  1651103         Atambua      ID     -9.11     124.89         88.77
# 568  1632694   Pangkalanbuun      ID     -2.68     111.62         76.59
# 574  3894426       Coyhaique      CL    -45.58     -72.07         48.20
# 578   965528      Phalaborwa      ZA    -23.94      31.14         62.60
#
#      Humidity (%)  Cloudiness (%)  Wind Speed (mph)        Date
# 2              82              14              8.05  1602901814
# 3              88              40              5.82  1602901814
# 4              65              40             19.46  1602901815
# 6              52               1              4.70  1602901815
# 12             73               1             18.48  1602901816
# ..            ...             ...               ...         ...
# 565            62              20             11.41  1602901673
# 566            43              31              2.98  1602901902
# 568            92             100              1.72  1602901902
# 574            76              12              2.24  1602901903
# 578            88              74              4.70  1602901904
#
# [174 rows x 10 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
N_maxtemp= Northern_cities["Max Temp (F)"]
N_latitude = Northern_cities["Latitude"]

correlation1 = st.pearsonr(N_latitude, N_maxtemp)

scatter1 = plt.scatter(N_latitude, N_maxtemp, marker="o", facecolors="blue", edgecolors="black", alpha=0.5)
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_latitude, N_maxtemp)

regress_values = N_latitude * slope + intercept

line_eq1 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The correlation between Latitude and Maximum Temperature is {round(correlation1[0],2)}, indicating strong negative correlation.")
print(f"The linear regression equation is {line_eq1}.")
print(f"The r-squared is: {round(rvalue**2,2)}")

plt.plot(N_latitude,regress_values,"r-")
plt.title("Northern Hemisphere - Max Temp vs. Latitude")
plt.ylabel("Maximum Temperature (F)")
plt.xlabel("Northern Latitudes")
plt.yticks(np.arange(0, 100, 10))
plt.xlim(0, 80)
plt.savefig("Ncities_lat_temp.png")
plt.show()
plt.tight_layout()
# Out:
# The correlation between Latitude and Maximum Temperature is -0.87, indicating strong negative correlation.
# The linear regression equation is y = -0.86x + 89.37.
# The r-squared is: 0.76

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
S_maxtemp= Southern_cities["Max Temp (F)"]
S_latitude = Southern_cities["Latitude"]

correlation2 = st.pearsonr(S_latitude, S_maxtemp)

scatter2 = plt.scatter(S_latitude, S_maxtemp, marker="o", facecolors="blue", edgecolors="black", alpha=0.5)

(slope2, intercept2, rvalue2, pvalue2, stderr2) = linregress(S_latitude, S_maxtemp)
regress_values2 = S_latitude * slope2 + intercept2

line_eq2 = "y = " + str(round(slope2,2)) + "x + " + str(round(intercept2,2))

print(f"The correlation between Latitude and Maximum Temperature is {round(correlation2[0],2)}, indicating moderate positive correlation.")
print(f"The linear regression equation is {line_eq2}.")
print(f"The r-squared is: {round(rvalue2**2,2)}")

plt.plot(S_latitude,regress_values2,"r-")
plt.title("Southern Hemisphere - Max Temp vs. Latitude")
plt.ylabel("Maximum Temperature (F)")
plt.xlabel("Southern Latitudes")
plt.yticks(np.arange(0, 100, 10))
plt.xlim(-60, 0)
plt.savefig("Scities_lat_temp.png")
plt.show()
plt.tight_layout()
# Out:
# The correlation between Latitude and Maximum Temperature is 0.66, indicating moderate positive correlation.
# The linear regression equation is y = 0.59x + 83.16.
# The r-squared is: 0.43

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
N_humidity= Northern_cities["Humidity (%)"]

correlation3 = st.pearsonr(N_latitude, N_humidity)

scatter3 = plt.scatter(N_latitude, N_humidity, marker="o", facecolors="blue", edgecolors="black", alpha=0.5)
(slope3, intercept3, rvalue3, pvalue3, stderr3) = linregress(N_latitude, N_humidity)

regress_values3 = N_latitude * slope3 + intercept3

line_eq3 = "y = " + str(round(slope3,2)) + "x + " + str(round(intercept3,2))

print(f"The correlation between Latitude and Humidity is {round(correlation3[0],2)}, indicating no correlation.")
print(f"The linear regression equation is {line_eq3}.")
print(f"The r-squared is: {round(rvalue3**2,2)}")

plt.plot(N_latitude,regress_values3,"r-")
plt.title("Northern Hemisphere - Max Temp vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Northern Latitudes")
plt.yticks(np.arange(0, 100, 10))
plt.xlim(0, 80)
plt.savefig("Ncities_lat_humid.png")
plt.show()
plt.tight_layout()
# Out:
# The correlation between Latitude and Humidity is 0.18, indicating no correlation.
# The linear regression equation is y = 0.19x + 67.39.
# The r-squared is: 0.03

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
S_humidity = Southern_cities["Humidity (%)"]

correlation4 = st.pearsonr(S_latitude, S_humidity )

scatter4 = plt.scatter(S_latitude, S_humidity, marker="o", facecolors="blue", edgecolors="black", alpha=0.5)

(slope4, intercept4, rvalue4, pvalue4, stderr4) = linregress(S_latitude, S_humidity)
regress_values4 = S_latitude * slope4 + intercept4

line_eq4 = "y = " + str(round(slope4,2)) + "x + " + str(round(intercept4,2))

print(f"The correlation between Latitude and Humidity is {round(correlation4[0],2)}, indicating no correlation.")
print(f"The linear regression equation is {line_eq4}.")
print(f"The r-squared is: {round(rvalue4**2,2)}")

plt.plot(S_latitude,regress_values4,"r-")
plt.title("Southern Hemisphere - Max Temp vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Southern Latitudes")
plt.yticks(np.arange(0, 100, 10))
plt.xlim(-60, 0)
plt.savefig("Scities_lat_humid.png")
plt.show()
plt.tight_layout()
# Out:
# The correlation between Latitude and Humidity is 0.06, indicating no correlation.
# The linear regression equation is y = 0.09x + 71.49.
# The r-squared is: 0.0

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
N_cloudy= Northern_cities["Cloudiness (%)"]

correlation5 = st.pearsonr(N_latitude, N_cloudy)

scatter5 = plt.scatter(N_latitude, N_cloudy, marker="o", facecolors="blue", edgecolors="black", alpha=0.5)
(slope5, intercept5, rvalue5, pvalue5, stderr5) = linregress(N_latitude, N_cloudy)

regress_values5 = N_latitude * slope5 + intercept5

line_eq5 = "y = " + str(round(slope5,2)) + "x + " + str(round(intercept5,2))

print(f"The correlation between Latitude and Humidity is {round(correlation5[0],2)}, indicating no correlation.")
print(f"The linear regression equation is {line_eq5}.")
print(f"The r-squared is: {round(rvalue5**2,2)}")

plt.plot(N_latitude,regress_values5,"r-")
plt.title("Northern Hemisphere - Max Temp vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Northern Latitudes")
plt.yticks(np.arange(0, 100, 10))
plt.xlim(0, 80)
plt.savefig("Ncities_lat_cloud.png")
plt.show()
plt.tight_layout()
# Out:
# The correlation between Latitude and Humidity is 0.17, indicating no correlation.
# The linear regression equation is y = 0.34x + 41.71.
# The r-squared is: 0.03

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
S_cloudy = Southern_cities["Cloudiness (%)"]

correlation6 = st.pearsonr(S_latitude, S_cloudy)

scatter6 = plt.scatter(S_latitude, S_cloudy, marker="o", facecolors="blue", edgecolors="black", alpha=0.5)

(slope6, intercept6, rvalue6, pvalue6, stderr6) = linregress(S_latitude, S_cloudy)
regress_values6 = S_latitude * slope6 + intercept6

line_eq6 = "y = " + str(round(slope6,2)) + "x + " + str(round(intercept6,2))

print(f"The correlation between Latitude and Cloudiness is {round(correlation6[0],2)}, indicating no correlation.")
print(f"The linear regression equation is {line_eq6}.")
print(f"The r-squared is: {round(rvalue6**2,2)}")

plt.plot(S_latitude,regress_values6,"r-")
plt.title("Southern Hemisphere - Max Temp vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Southern Latitudes")
plt.yticks(np.arange(0, 100, 10))
plt.xlim(-60, 0)
plt.savefig("Scities_lat_cloud.png")
plt.show()
plt.tight_layout()
# Out:
# The correlation between Latitude and Cloudiness is 0.04, indicating no correlation.
# The linear regression equation is y = 0.1x + 50.02.
# The r-squared is: 0.0

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
N_wind= Northern_cities["Wind Speed (mph)"]

correlation7 = st.pearsonr(N_latitude, N_wind)

scatter7 = plt.scatter(N_latitude, N_wind, marker="o", facecolors="blue", edgecolors="black", alpha=0.5)
(slope7, intercept7, rvalue7, pvalue7, stderr7) = linregress(N_latitude, N_wind)

regress_values7 = N_latitude * slope7 + intercept7

line_eq7 = "y = " + str(round(slope7,2)) + "x + " + str(round(intercept7,2))

print(f"The correlation between Latitude and Wind Speed is {round(correlation7[0],2)}, indicating very weak positive correlation.")
print(f"The linear regression equation is {line_eq7}.")
print(f"The r-squared is: {round(rvalue7**2,2)}")

plt.plot(N_latitude,regress_values7,"r-")
plt.title("Northern Hemisphere - Max Temp vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Northern Latitudes")
plt.yticks(np.arange(0, 60, 10))
plt.xlim(0, 80)
plt.savefig("Ncities_lat_wind.png")
plt.show()
plt.tight_layout()
# Out:
# The correlation between Latitude and Wind Speed is 0.26, indicating very weak positive correlation.
# The linear regression equation is y = 0.07x + 4.67.
# The r-squared is: 0.07

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
S_wind = Southern_cities["Wind Speed (mph)"]

correlation8 = st.pearsonr(S_latitude, S_wind)

scatter8 = plt.scatter(S_latitude, S_wind, marker="o", facecolors="blue", edgecolors="black", alpha=0.5)

(slope8, intercept8, rvalue8, pvalue8, stderr8) = linregress(S_latitude, S_wind)
regress_values8 = S_latitude * slope8 + intercept8

line_eq8 = "y = " + str(round(slope8,2)) + "x + " + str(round(intercept8,2))

print(f"The correlation between Latitude and Wind Speed is {round(correlation8[0],2)}, indicating no correlation.")
print(f"The linear regression equation is {line_eq8}.")
print(f"The r-squared is: {round(rvalue8**2,2)}")

plt.plot(S_latitude,regress_values8,"r-")
plt.title("Southern Hemisphere - Max Temp vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Southern Latitudes")
plt.yticks(np.arange(0, 60, 10))
plt.xlim(-60, 0)
plt.savefig("Scities_lat_wind.png")
plt.show()
plt.tight_layout()
# Out:
# The correlation between Latitude and Wind Speed is -0.14, indicating no correlation.
# The linear regression equation is y = -0.06x + 6.81.
# The r-squared is: 0.02
